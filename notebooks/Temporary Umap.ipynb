# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import umap
import umap.plot

import sys
sys.path.append('../')
from src.clusterability import Dataset

from src.typology import HuronTypology
from src.contour import Contour

# %%
dataset = Dataset('combined-phrase')

# %%
contours = dataset.representation('pitch_tonicized', limit=10000)
labels = dataset.df['dataset'].values[dataset.subset_index(limit=10000)]

# %%
# typology = HuronTypology(1.3)
# labels = [typology.classify(Contour(c)) for c in contours]

# %%
mapper = umap.UMAP(random_state=42).fit(contours)

# %%
umap.plot.points(mapper, labels=labels)
