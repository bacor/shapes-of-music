# %% [markdown]
# # Dip's

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

import sys
sys.path.append('../')
from helpers import cm2inch
from melodic_contour import *
matplotlib.style.use('styles.mplstyle')

from scipy.spatial import distance_matrix
from unidip.dip import diptst as diptest

# %%
def show_bivariate_data(data):
    plt.figure(figsize=cm2inch(12, 4))
    plt.subplot(131)
    x, y = data.T
    plt.plot(x, y, '.', alpha=.2)
    plt.title('A. Data')

    plt.subplot(132)
    dm = distance_matrix(data, data)
    plt.imshow(dm)
    plt.title('B. Distance matrix')

    plt.subplot(133)
    sns.histplot(np.msort(dm.ravel()), kde=True, lw=0);
    plt.title('C. Distr. of pairwise distances');
    plt.tight_layout()

# %%
data = np.concatenate([
        np.random.multivariate_normal([0, 0], [[1, 0], [0, 1]], 200),
        np.random.multivariate_normal([6, 0], [[1, 0], [0, 1]], 200),
        np.random.multivariate_normal([3, 10], [[1, 0], [0, 1]], 200)
])
show_bivariate_data(data)
plt.savefig('../figures/figY-dip-dist.pdf')

# %%
data = np.concatenate([
        np.random.multivariate_normal([0, 0], [[1, 0], [0, 1]], 200),
        np.random.multivariate_normal([6, 0], [[1, 0], [0, 1]], 200),
        np.random.multivariate_normal([3, 10], [[1, 0], [0, 1]], 200),
        (np.random.rand(100, 2) - .5) * 4
])
# show_bivariate_data(data)

# %%
d = (np.random.rand(100, 2) * 4

# %%
plt.scatter(d[:, 0], d[:, 1]);

# %%
plt.figure(figsize=cm2inch(12, 4))
plt.subplot(131)
data = np.concatenate([
        np.random.multivariate_normal([0, 0], [[1, 0], [0, 1]], 200),
        np.random.multivariate_normal([6, 0], [[1, 0], [0, 1]], 200),
        np.random.multivariate_normal([3, 10], [[1, 0], [0, 1]], 200),
        np.random.rand(100, 2) * 15 + np.array([[-2.5, -2.5]])
])
print(data.shape)
x, y = data.T
plt.plot(x, y, '.', alpha=.2)
plt.title('A. Data')

plt.subplot(132)
dm = distance_matrix(data, data)
plt.imshow(dm)
plt.title('B. Distance matrix')

plt.subplot(133)
sns.histplot(np.msort(dm.ravel()), kde=True);
plt.title('C. Distr. of pairwise distances');
plt.tight_layout()
# Out:
# (700, 2)

# %%
data = np.random.multivariate_normal([0, 0], [[1, 0], [0, 1]], 200)
show_bivariate_data(data)

# %%
np.r_[np.random.randn(50), np.random.randn(50)+3]
# Out:
# array([-0.81566073,  0.37666271,  0.79245625, -1.72339555,  1.22267392,
#        -0.84431645, -1.62680476, -0.98128997,  1.24245265, -0.23992326,
#         0.62057109,  0.31048966, -0.32472479, -0.62042461, -1.63144208,
#        -1.93465937,  1.83580826, -2.33637523, -0.18408403,  0.01205999,
#         0.45504304, -1.1396103 ,  1.11306348, -0.34483814, -0.66345595,
#        -1.53319044,  0.71733899, -0.22733424, -0.69249765, -1.47289841,
#        -0.44588575, -0.4109452 ,  0.57526362,  0.75120185,  0.15475504,
#        -0.25330255,  0.8032116 , -0.93022272, -0.49749112, -0.77049493,
#        -0.06788086, -0.05232604, -0.62876781,  0.16199546,  1.03227555,
#         0.07251007, -2.10187301,  1.26122873,  1.24311033, -1.86160686,
#         3.09469121,  1.8832923 ,  1.26828965,  3.20560162,  3.96593667,
#         3.58498535,  4.22035571,  2.87972808,  4.43132276,  2.86139781,
#         3.56519407,  4.8862037 ,  1.28240459,  1.80368105,  2.75486819,
#         2.03085454,  1.63988585,  3.22853198,  1.29151488,  1.25883691,
#         3.08635299,  4.28429734,  4.04335574,  3.29381566,  2.83882382,
#         2.90220908,  4.01192161,  2.98024593,  1.99208127,  2.97557759,
#         3.08373206,  2.68882161,  3.20738312,  2.8512017 ,  1.61309707,
#         2.40587006,  2.99457931,  3.85452405,  1.58718651,  1.52188744,
#         5.34351276,  3.50667271,  4.87750003,  4.24621788,  2.79296308,
#         3.37026641,  2.94659104,  1.40206643,  2.38842365,  4.3238143 ])

# %%
data = np.r_[np.random.randn(100), np.random.randn(100)+6]
plt.subplot(121)
sns.distplot(data)
plt.subplot(122)
sns.ecdfplot(data)
# Out:
# /Users/bas/repos/papers/contour-typology/env/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.ecdfplot(np.msort(dm.ravel()))

# %%
data = np.concatenate([
        np.random.multivariate_normal([0, 0], [[1, 0], [0, 1]], 200),
        np.random.multivariate_normal([6, 0], [[1, 0], [0, 1]], 200),
        np.random.multivariate_normal([3, 10], [[1, 0], [0, 1]], 200),
        np.random.rand(10, 2) * 10 + np.array([[-2.5, -2.5]])
])

# %%
np.random.rand(10, 2) * 10 + np.array([[-25, -2.5]])
# Out:
# array([[-19.63762846,   0.19745518],
#        [-20.31592613,  -0.18368668],
#        [-24.01889913,   6.73593965],
#        [-15.34431909,   1.52356886],
#        [-20.05998846,   1.4452975 ],
#        [-19.43649957,  -1.96945632],
#        [-24.49255595,   0.40917312],
#        [-18.39632811,   2.155001  ],
#        [-17.82214354,   1.90582233],
#        [-22.94367192,   1.72452368]])
